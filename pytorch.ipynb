# %%
#tabular data classification

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torchsummary import summary

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#pytorch cant detect cpu directly
device =  'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
dataset = pd.read_csv('/content/riceClassification.csv')

# %%
dataset.head()
# Out:
#    id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0   1  4537        92.229316        64.012769      0.719916        4677
# 1   2  2872        74.691881        51.400454      0.725553        3015
# 2   3  3048        76.293164        52.043491      0.731211        3132
# 3   4  3073        77.033628        51.928487      0.738639        3157
# 4   5  3693        85.124785        56.374021      0.749282        3802
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0      76.004525  0.657536    273.085   0.764510      1.440796      1
# 1      60.471018  0.713009    208.317   0.831658      1.453137      1
# 2      62.296341  0.759153    210.012   0.868434      1.465950      1
# 3      62.551300  0.783529    210.657   0.870203      1.483456      1
# 4      68.571668  0.769375    230.332   0.874743      1.510000      1

# %%
dataset.dropna(inplace=True)

# %%
dataset =dataset.drop(['id'], axis = 1)

# %%
#normalization
original = dataset.copy()

# %%
for column in dataset.columns:
  dataset[column] = (dataset[column]/ (dataset[column].abs().max()))

# %%
dataset.head()
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  0.444368         0.503404         0.775435      0.744658    0.424873
# 1  0.281293         0.407681         0.622653      0.750489    0.273892
# 2  0.298531         0.416421         0.630442      0.756341    0.284520
# 3  0.300979         0.420463         0.629049      0.764024    0.286791
# 4  0.361704         0.464626         0.682901      0.775033    0.345385
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0       0.666610  0.741661   0.537029   0.844997      0.368316    1.0
# 1       0.530370  0.804230   0.409661   0.919215      0.371471    1.0
# 2       0.546380  0.856278   0.412994   0.959862      0.374747    1.0
# 3       0.548616  0.883772   0.414262   0.961818      0.379222    1.0
# 4       0.601418  0.867808   0.452954   0.966836      0.386007    1.0

# %%
x = np.array(dataset.iloc[:,:-1]) #until last
y = np.array(dataset.iloc[:,-1]) #only last

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)
# Out:
# (12729, 10)
# (2728, 10)
# (2728, 10)

# %%
#convert the data into py torch data

# %%
class dataset(Dataset):
  def __init__(self,x,y):
    self.x=torch.tensor(x,dtype = torch.float32).to(device)
    self.y=torch.tensor(y,dtype = torch.float32).to(device)
  def __len__(self):
    return len(self.x)
  def __getitem__(self,idx):
    return self.x[idx],self.y[idx]

# %%
training_data = dataset(x_train,y_train)
validation_data = dataset(x_val,y_val)
testing_data = dataset(x_test,y_test)

# %%
#data loader to loop through
train_dataloader = DataLoader(training_data,batch_size=32,shuffle=True)
val_dataloader = DataLoader(validation_data,batch_size=32,shuffle=True)
test_dataloader = DataLoader(testing_data,batch_size=32,shuffle=True)

# %%
#build own model
HIDDEN_NEURONS =10
class mymodel(nn.Module):
  def __init__(self):
    super(mymodel, self).__init__()

    self.input_layer = nn.Linear(x.shape[1], HIDDEN_NEURONS)
    self.linear = nn.Linear(HIDDEN_NEURONS, 1)
    self.sigmoid = nn.Sigmoid()

  def forward(self,x):
    x = self.input_layer(x)
    x = self.linear(x)
    x = self.sigmoid(x)
    return x


model = mymodel().to(device)

# %%
summary(model, (x.shape[1],))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 10]             110
#             Linear-2                    [-1, 1]              11
#            Sigmoid-3                    [-1, 1]               0
# ================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------

# %%
optimizer = Adam(model.parameters(), lr = 1e-3)

# ✅ Use BCEWithLogitsLoss for binary classification
criterion = nn.BCEWithLogitsLoss()

total_loss_train_plot = []
total_loss_val_plot = []
total_acc_train_plot = []
total_acc_val_plot = []

for epoch in range(100):
    total_loss_train = 0
    total_loss_val = 0
    total_acc_train = 0
    total_acc_val = 0

    # ---------------- TRAIN ----------------
    model.train()
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        # forward pass
        prediction = model(inputs)

        # match dimensions: [batch_size, 1]
        labels = labels.float().unsqueeze(1)

        batch_loss = criterion(prediction, labels)
        total_loss_train += batch_loss.item()

        # accuracy: sigmoid + round for binary classification
        predicted = torch.sigmoid(prediction).round()
        acc = (predicted == labels).sum().item()
        total_acc_train += acc

        # backward + optimize
        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()

    # ---------------- VALIDATION ----------------
    model.eval()
    with torch.no_grad():
        for inputs, labels in val_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            prediction = model(inputs)
            labels = labels.float().unsqueeze(1)

            batch_loss = criterion(prediction, labels)
            total_loss_val += batch_loss.item()

            predicted = torch.sigmoid(prediction).round()
            acc = (predicted == labels).sum().item()
            total_acc_val += acc

    # ---------------- LOGGING ----------------
    avg_train_loss = total_loss_train / len(train_dataloader)
    avg_val_loss   = total_loss_val / len(val_dataloader)

    avg_train_acc = total_acc_train / len(training_data) * 100
    avg_val_acc   = total_acc_val / len(validation_data) * 100

    total_loss_train_plot.append(round(avg_train_loss, 4))
    total_loss_val_plot.append(round(avg_val_loss, 4))
    total_acc_train_plot.append(round(avg_train_acc, 4))
    total_acc_val_plot.append(round(avg_val_acc, 4))

    print(f'Epoch {epoch+1}: '
          f'Train Loss = {avg_train_loss:.4f}, Train Acc = {avg_train_acc:.2f}%, '
          f'Val Loss = {avg_val_loss:.4f}, Val Acc = {avg_val_acc:.2f}%')
    print("=" * 40)
# Out:
# Epoch 1: Train Loss = 0.4956, Train Acc = 55.02%, Val Loss = 0.4916, Val Acc = 56.30%
# ========================================
# Epoch 2: Train Loss = 0.4948, Train Acc = 55.83%, Val Loss = 0.4914, Val Acc = 58.72%
# ========================================
# Epoch 3: Train Loss = 0.4943, Train Acc = 57.68%, Val Loss = 0.4898, Val Acc = 60.04%
# ========================================
# Epoch 4: Train Loss = 0.4940, Train Acc = 60.61%, Val Loss = 0.4912, Val Acc = 61.11%
# ========================================
# Epoch 5: Train Loss = 0.4938, Train Acc = 63.33%, Val Loss = 0.4904, Val Acc = 67.30%
# ========================================
# Epoch 6: Train Loss = 0.4936, Train Acc = 66.68%, Val Loss = 0.4892, Val Acc = 68.44%
# ========================================
# Epoch 7: Train Loss = 0.4935, Train Acc = 69.56%, Val Loss = 0.4899, Val Acc = 70.56%
# ========================================
# Epoch 8: Train Loss = 0.4934, Train Acc = 72.10%, Val Loss = 0.4908, Val Acc = 77.68%
# ========================================
# Epoch 9: Train Loss = 0.4932, Train Acc = 74.56%, Val Loss = 0.4897, Val Acc = 76.54%
# ========================================
# Epoch 10: Train Loss = 0.4932, Train Acc = 76.60%, Val Loss = 0.4903, Val Acc = 80.32%
# ========================================
# Epoch 11: Train Loss = 0.4930, Train Acc = 78.54%, Val Loss = 0.4900, Val Acc = 79.99%
# ========================================
# Epoch 12: Train Loss = 0.4931, Train Acc = 80.01%, Val Loss = 0.4887, Val Acc = 81.78%
# ========================================
# Epoch 13: Train Loss = 0.4931, Train Acc = 81.23%, Val Loss = 0.4890, Val Acc = 82.51%
# ========================================
# Epoch 14: Train Loss = 0.4929, Train Acc = 82.16%, Val Loss = 0.4903, Val Acc = 86.33%
# ========================================
# Epoch 15: Train Loss = 0.4929, Train Acc = 82.96%, Val Loss = 0.4887, Val Acc = 87.28%
# ========================================
# Epoch 16: Train Loss = 0.4929, Train Acc = 84.37%, Val Loss = 0.4889, Val Acc = 84.31%
# ========================================
# Epoch 17: Train Loss = 0.4928, Train Acc = 84.98%, Val Loss = 0.4893, Val Acc = 86.22%
# ========================================
# Epoch 18: Train Loss = 0.4929, Train Acc = 85.48%, Val Loss = 0.4890, Val Acc = 87.72%
# ========================================
# Epoch 19: Train Loss = 0.4927, Train Acc = 86.09%, Val Loss = 0.4901, Val Acc = 87.68%
# ========================================
# Epoch 20: Train Loss = 0.4927, Train Acc = 86.74%, Val Loss = 0.4890, Val Acc = 89.22%
# ========================================
# Epoch 21: Train Loss = 0.4929, Train Acc = 87.02%, Val Loss = 0.4899, Val Acc = 89.37%
# ========================================
# Epoch 22: Train Loss = 0.4926, Train Acc = 87.63%, Val Loss = 0.4896, Val Acc = 91.57%
# ========================================
# Epoch 23: Train Loss = 0.4926, Train Acc = 88.15%, Val Loss = 0.4899, Val Acc = 91.72%
# ========================================
# Epoch 24: Train Loss = 0.4927, Train Acc = 88.38%, Val Loss = 0.4904, Val Acc = 90.62%
# ========================================
# Epoch 25: Train Loss = 0.4927, Train Acc = 89.05%, Val Loss = 0.4883, Val Acc = 90.36%
# ========================================
# Epoch 26: Train Loss = 0.4925, Train Acc = 89.13%, Val Loss = 0.4910, Val Acc = 93.95%
# ========================================
# Epoch 27: Train Loss = 0.4926, Train Acc = 89.70%, Val Loss = 0.4889, Val Acc = 92.63%
# ========================================
# Epoch 28: Train Loss = 0.4925, Train Acc = 89.79%, Val Loss = 0.4882, Val Acc = 90.58%
# ========================================
# Epoch 29: Train Loss = 0.4926, Train Acc = 89.90%, Val Loss = 0.4893, Val Acc = 88.71%
# ========================================
# Epoch 30: Train Loss = 0.4926, Train Acc = 90.10%, Val Loss = 0.4895, Val Acc = 91.35%
# ========================================
# Epoch 31: Train Loss = 0.4925, Train Acc = 90.45%, Val Loss = 0.4891, Val Acc = 92.01%
# ========================================
# Epoch 32: Train Loss = 0.4925, Train Acc = 90.65%, Val Loss = 0.4901, Val Acc = 92.23%
# ========================================
# Epoch 33: Train Loss = 0.4925, Train Acc = 90.71%, Val Loss = 0.4886, Val Acc = 91.90%
# ========================================
# Epoch 34: Train Loss = 0.4926, Train Acc = 90.82%, Val Loss = 0.4891, Val Acc = 92.74%
# ========================================
# Epoch 35: Train Loss = 0.4926, Train Acc = 91.17%, Val Loss = 0.4882, Val Acc = 92.23%
# ========================================
# Epoch 36: Train Loss = 0.4924, Train Acc = 91.31%, Val Loss = 0.4902, Val Acc = 91.90%
# ========================================
# Epoch 37: Train Loss = 0.4925, Train Acc = 91.56%, Val Loss = 0.4890, Val Acc = 91.75%
# ========================================
# Epoch 38: Train Loss = 0.4925, Train Acc = 91.48%, Val Loss = 0.4890, Val Acc = 92.93%
# ========================================
# Epoch 39: Train Loss = 0.4925, Train Acc = 91.58%, Val Loss = 0.4881, Val Acc = 92.27%
# ========================================
# Epoch 40: Train Loss = 0.4924, Train Acc = 91.90%, Val Loss = 0.4900, Val Acc = 94.28%
# ========================================
# Epoch 41: Train Loss = 0.4925, Train Acc = 92.06%, Val Loss = 0.4889, Val Acc = 92.78%
# ========================================
# Epoch 42: Train Loss = 0.4926, Train Acc = 91.85%, Val Loss = 0.4899, Val Acc = 94.61%
# ========================================
# Epoch 43: Train Loss = 0.4924, Train Acc = 92.25%, Val Loss = 0.4889, Val Acc = 92.82%
# ========================================
# Epoch 44: Train Loss = 0.4924, Train Acc = 92.32%, Val Loss = 0.4891, Val Acc = 91.90%
# ========================================
# Epoch 45: Train Loss = 0.4926, Train Acc = 92.30%, Val Loss = 0.4891, Val Acc = 94.02%
# ========================================
# Epoch 46: Train Loss = 0.4926, Train Acc = 92.51%, Val Loss = 0.4885, Val Acc = 93.66%
# ========================================
# Epoch 47: Train Loss = 0.4925, Train Acc = 92.53%, Val Loss = 0.4890, Val Acc = 93.84%
# ========================================
# Epoch 48: Train Loss = 0.4925, Train Acc = 92.48%, Val Loss = 0.4890, Val Acc = 93.95%
# ========================================
# Epoch 49: Train Loss = 0.4924, Train Acc = 92.65%, Val Loss = 0.4892, Val Acc = 94.76%
# ========================================
# Epoch 50: Train Loss = 0.4924, Train Acc = 92.87%, Val Loss = 0.4881, Val Acc = 93.37%
# ========================================
# Epoch 51: Train Loss = 0.4924, Train Acc = 92.98%, Val Loss = 0.4896, Val Acc = 94.54%
# ========================================
# Epoch 52: Train Loss = 0.4924, Train Acc = 92.85%, Val Loss = 0.4896, Val Acc = 94.76%
# ========================================
# Epoch 53: Train Loss = 0.4923, Train Acc = 92.95%, Val Loss = 0.4890, Val Acc = 95.31%
# ========================================
# Epoch 54: Train Loss = 0.4924, Train Acc = 93.04%, Val Loss = 0.4898, Val Acc = 94.87%
# ========================================
# Epoch 55: Train Loss = 0.4923, Train Acc = 93.23%, Val Loss = 0.4904, Val Acc = 94.24%
# ========================================
# Epoch 56: Train Loss = 0.4922, Train Acc = 93.20%, Val Loss = 0.4893, Val Acc = 95.38%
# ========================================
# Epoch 57: Train Loss = 0.4924, Train Acc = 93.23%, Val Loss = 0.4890, Val Acc = 95.12%
# ========================================
# Epoch 58: Train Loss = 0.4924, Train Acc = 93.50%, Val Loss = 0.4885, Val Acc = 95.38%
# ========================================
# Epoch 59: Train Loss = 0.4924, Train Acc = 93.57%, Val Loss = 0.4890, Val Acc = 94.57%
# ========================================
# Epoch 60: Train Loss = 0.4923, Train Acc = 93.46%, Val Loss = 0.4900, Val Acc = 95.60%
# ========================================
# Epoch 61: Train Loss = 0.4924, Train Acc = 93.57%, Val Loss = 0.4900, Val Acc = 95.38%
# ========================================
# Epoch 62: Train Loss = 0.4924, Train Acc = 93.53%, Val Loss = 0.4886, Val Acc = 94.76%
# ========================================
# Epoch 63: Train Loss = 0.4923, Train Acc = 93.89%, Val Loss = 0.4897, Val Acc = 94.24%
# ========================================
# Epoch 64: Train Loss = 0.4922, Train Acc = 93.69%, Val Loss = 0.4894, Val Acc = 95.38%
# ========================================
# Epoch 65: Train Loss = 0.4925, Train Acc = 94.00%, Val Loss = 0.4872, Val Acc = 94.46%
# ========================================
# Epoch 66: Train Loss = 0.4924, Train Acc = 93.86%, Val Loss = 0.4889, Val Acc = 94.65%
# ========================================
# Epoch 67: Train Loss = 0.4923, Train Acc = 93.84%, Val Loss = 0.4877, Val Acc = 94.76%
# ========================================
# Epoch 68: Train Loss = 0.4925, Train Acc = 93.76%, Val Loss = 0.4892, Val Acc = 95.38%
# ========================================
# Epoch 69: Train Loss = 0.4924, Train Acc = 93.84%, Val Loss = 0.4900, Val Acc = 95.38%
# ========================================
# Epoch 70: Train Loss = 0.4924, Train Acc = 94.11%, Val Loss = 0.4888, Val Acc = 95.38%
# ========================================
# Epoch 71: Train Loss = 0.4924, Train Acc = 94.01%, Val Loss = 0.4872, Val Acc = 94.43%
# ========================================
# Epoch 72: Train Loss = 0.4924, Train Acc = 94.16%, Val Loss = 0.4887, Val Acc = 95.38%
# ========================================
# Epoch 73: Train Loss = 0.4922, Train Acc = 94.22%, Val Loss = 0.4892, Val Acc = 95.38%
# ========================================
# Epoch 74: Train Loss = 0.4923, Train Acc = 94.23%, Val Loss = 0.4887, Val Acc = 94.61%
# ========================================
# Epoch 75: Train Loss = 0.4923, Train Acc = 94.24%, Val Loss = 0.4894, Val Acc = 95.31%
# ========================================
# Epoch 76: Train Loss = 0.4923, Train Acc = 94.19%, Val Loss = 0.4898, Val Acc = 95.34%
# ========================================
# Epoch 77: Train Loss = 0.4923, Train Acc = 94.01%, Val Loss = 0.4889, Val Acc = 95.56%
# ========================================
# Epoch 78: Train Loss = 0.4923, Train Acc = 94.52%, Val Loss = 0.4882, Val Acc = 95.38%
# ========================================
# Epoch 79: Train Loss = 0.4924, Train Acc = 94.23%, Val Loss = 0.4896, Val Acc = 95.34%
# ========================================
# Epoch 80: Train Loss = 0.4923, Train Acc = 94.42%, Val Loss = 0.4899, Val Acc = 96.19%
# ========================================
# Epoch 81: Train Loss = 0.4923, Train Acc = 94.35%, Val Loss = 0.4893, Val Acc = 94.46%
# ========================================
# Epoch 82: Train Loss = 0.4925, Train Acc = 94.58%, Val Loss = 0.4888, Val Acc = 95.56%
# ========================================
# Epoch 83: Train Loss = 0.4924, Train Acc = 94.49%, Val Loss = 0.4893, Val Acc = 95.38%
# ========================================
# Epoch 84: Train Loss = 0.4923, Train Acc = 94.65%, Val Loss = 0.4890, Val Acc = 94.17%
# ========================================
# Epoch 85: Train Loss = 0.4922, Train Acc = 94.45%, Val Loss = 0.4893, Val Acc = 95.75%
# ========================================
# Epoch 86: Train Loss = 0.4923, Train Acc = 94.62%, Val Loss = 0.4897, Val Acc = 95.38%
# ========================================
# Epoch 87: Train Loss = 0.4923, Train Acc = 94.68%, Val Loss = 0.4886, Val Acc = 95.49%
# ========================================
# Epoch 88: Train Loss = 0.4924, Train Acc = 94.70%, Val Loss = 0.4906, Val Acc = 95.27%
# ========================================
# Epoch 89: Train Loss = 0.4924, Train Acc = 94.65%, Val Loss = 0.4881, Val Acc = 95.38%
# ========================================
# Epoch 90: Train Loss = 0.4923, Train Acc = 94.50%, Val Loss = 0.4887, Val Acc = 95.53%
# ========================================
# Epoch 91: Train Loss = 0.4924, Train Acc = 94.79%, Val Loss = 0.4889, Val Acc = 95.60%
# ========================================
# Epoch 92: Train Loss = 0.4923, Train Acc = 94.78%, Val Loss = 0.4887, Val Acc = 95.67%
# ========================================
# Epoch 93: Train Loss = 0.4924, Train Acc = 94.85%, Val Loss = 0.4892, Val Acc = 95.01%
# ========================================
# Epoch 94: Train Loss = 0.4922, Train Acc = 94.49%, Val Loss = 0.4897, Val Acc = 95.93%
# ========================================
# Epoch 95: Train Loss = 0.4922, Train Acc = 94.83%, Val Loss = 0.4895, Val Acc = 95.38%
# ========================================
# Epoch 96: Train Loss = 0.4922, Train Acc = 95.12%, Val Loss = 0.4892, Val Acc = 94.02%
# ========================================
# Epoch 97: Train Loss = 0.4924, Train Acc = 94.47%, Val Loss = 0.4898, Val Acc = 95.82%
# ========================================
# Epoch 98: Train Loss = 0.4923, Train Acc = 95.07%, Val Loss = 0.4885, Val Acc = 95.56%
# ========================================
# Epoch 99: Train Loss = 0.4923, Train Acc = 94.98%, Val Loss = 0.4899, Val Acc = 95.67%
# ========================================
# Epoch 100: Train Loss = 0.4922, Train Acc = 95.09%, Val Loss = 0.4895, Val Acc = 96.33%
# ========================================

# %%
with torch.no_grad():
  total_loss_test =0;
  total_acc_test =0;
  for data in test_dataloader:
    inputs, labels = data
    prediction = model(inputs).squeeze(1)

    batch_loss = criterion(prediction, labels)
    total_loss_test += batch_loss.item()

    predicted = torch.sigmoid(prediction).round()
    acc = (predicted == labels).sum().item()
    total_acc_test += acc
print("acc : ",round(total_acc_test/len(testing_data)*100.4))
# Out:
# acc :  97
