# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
dataset.head()
# Out:
#                        name  year  ...  transmission         owner
# 0             Maruti 800 AC  2007  ...        Manual   First Owner
# 1  Maruti Wagon R LXI Minor  2007  ...        Manual   First Owner
# 2      Hyundai Verna 1.6 SX  2012  ...        Manual   First Owner
# 3    Datsun RediGO T Option  2017  ...        Manual   First Owner
# 4     Honda Amaze VX i-DTEC  2014  ...        Manual  Second Owner
#
# [5 rows x 8 columns]

# %%
dataset.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
dataset.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
dataset = dataset.replace({
    'fuel': {'Petrol': 0, 'Diesel': 1, 'CNG': 2,'LPG' : 3,'Electric' : 4},
    'seller_type': {'Dealer': 0, 'Individual': 1,'Trustmark Dealer':2},
    'transmission': {'Manual': 0, 'Automatic': 1},
    'owner': {'First Owner': 0, 'Second Owner': 1, 'Third Owner': 2, 'Fourth & Above Owner': 3, 'Test Drive Car': 4}
})
# Out:
# /tmp/ipython-input-196-4219971158.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset = dataset.replace({

# %%
dataset['owner'].value_counts()
# Out:
# owner
# 0    2832
# 1    1106
# 2     304
# 3      81
# 4      17
# Name: count, dtype: int64

# %%
dataset = dataset.replace({
    'fuel': {'Petrol': 0, 'Diesel': 1, 'CNG': 2,'LPG' : 3,'Electric' : 4},
    'seller_type': {'Dealer': 0, 'Individual': 1},
    'transmission': {'Manual': 0, 'Automatic': 1},
    'owner': {'First Owner': 0, 'Second Owner': 1, 'Third Owner': 2, 'Fourth & Above Owner': 3, 'Test Drive Car': 4}
})

# %%
x = dataset.drop(columns=['name','selling_price'],axis=1)
y = dataset['selling_price']/1000

# %%
print(x)
print(y)
# Out:
#       year  km_driven  fuel  seller_type  transmission  owner
# 0     2007      70000     0            1             0      0
# 1     2007      50000     0            1             0      0
# 2     2012     100000     1            1             0      0
# 3     2017      46000     0            1             0      0
# 4     2014     141000     1            1             0      1
# ...    ...        ...   ...          ...           ...    ...
# 4335  2014      80000     1            1             0      1
# 4336  2014      80000     1            1             0      1
# 4337  2009      83000     0            1             0      1
# 4338  2016      90000     1            1             0      0
# 4339  2016      40000     0            1             0      0
#
# [4340 rows x 6 columns]
# 0        60.000
# 1       135.000
# 2       600.000
# 3       250.000
# 4       450.000
#          ...
# 4335    409.999
# 4336    409.999
# 4337    110.000
# 4338    865.000
# 4339    225.000
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1,random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test_prediction = model.predict(x_test)

# %%
err  = r2_score(y_test,x_test_prediction)
print(err)
# Out:
# 0.3969328662905791

# %%
err = mean_absolute_error(y_test,x_test_prediction)
print(err)
# Out:
# 213.39662702777852

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
dataset.head()
# Out:
#                        name  year  ...  transmission         owner
# 0             Maruti 800 AC  2007  ...        Manual   First Owner
# 1  Maruti Wagon R LXI Minor  2007  ...        Manual   First Owner
# 2      Hyundai Verna 1.6 SX  2012  ...        Manual   First Owner
# 3    Datsun RediGO T Option  2017  ...        Manual   First Owner
# 4     Honda Amaze VX i-DTEC  2014  ...        Manual  Second Owner
#
# [5 rows x 8 columns]

# %%
dataset.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
dataset.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
dataset = dataset.replace({
    'fuel': {'Petrol': 0, 'Diesel': 1, 'CNG': 2,'LPG' : 3,'Electric' : 4},
    'seller_type': {'Dealer': 0, 'Individual': 1,'Trustmark Dealer':2},
    'transmission': {'Manual': 0, 'Automatic': 1},
    'owner': {'First Owner': 0, 'Second Owner': 1, 'Third Owner': 2, 'Fourth & Above Owner': 3, 'Test Drive Car': 4}
})
# Out:
# /tmp/ipython-input-211-4219971158.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset = dataset.replace({

# %%
dataset['owner'].value_counts()
# Out:
# owner
# 0    2832
# 1    1106
# 2     304
# 3      81
# 4      17
# Name: count, dtype: int64

# %%
dataset = dataset.replace({
    'fuel': {'Petrol': 0, 'Diesel': 1, 'CNG': 2,'LPG' : 3,'Electric' : 4},
    'seller_type': {'Dealer': 0, 'Individual': 1},
    'transmission': {'Manual': 0, 'Automatic': 1},
    'owner': {'First Owner': 0, 'Second Owner': 1, 'Third Owner': 2, 'Fourth & Above Owner': 3, 'Test Drive Car': 4}
})

# %%
x = dataset.drop(columns=['name','selling_price'],axis=1)
y = dataset['selling_price']/1000

# %%
print(x)
print(y)
# Out:
#       year  km_driven  fuel  seller_type  transmission  owner
# 0     2007      70000     0            1             0      0
# 1     2007      50000     0            1             0      0
# 2     2012     100000     1            1             0      0
# 3     2017      46000     0            1             0      0
# 4     2014     141000     1            1             0      1
# ...    ...        ...   ...          ...           ...    ...
# 4335  2014      80000     1            1             0      1
# 4336  2014      80000     1            1             0      1
# 4337  2009      83000     0            1             0      1
# 4338  2016      90000     1            1             0      0
# 4339  2016      40000     0            1             0      0
#
# [4340 rows x 6 columns]
# 0        60.000
# 1       135.000
# 2       600.000
# 3       250.000
# 4       450.000
#          ...
# 4335    409.999
# 4336    409.999
# 4337    110.000
# 4338    865.000
# 4339    225.000
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1,random_state=42)

# %%
model = Lasso()

# %%
model.fit(x_train,y_train)
# Out:
# Lasso()

# %%
x_test_prediction = model.predict(x_test)

# %%
err  = r2_score(y_test,x_test_prediction)
print(err)
# Out:
# 0.40060609535374303

# %%
err = mean_absolute_error(y_test,x_test_prediction)
print(err)
# Out:
# 212.59140554735836

# %%
x_test_prediction = model.predict(x_test.iloc[[67]])
print(x_test_prediction)
# Out:
# [144.97827698]
