# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.utils import resample
import pickle

# %%
dataset = pd.read_csv("/content/Rainfall.csv")

# %%
dataset.head()
# Out:
#    day  pressure   maxtemp  ...  sunshine           winddirection  windspeed
# 0    1     1025.9     19.9  ...       9.3                    80.0       26.3
# 1    2     1022.0     21.7  ...       0.6                    50.0       15.3
# 2    3     1019.7     20.3  ...       0.0                    40.0       14.2
# 3    4     1018.9     22.3  ...       1.0                    50.0       16.9
# 4    5     1015.9     21.3  ...       0.0                    40.0       13.7
#
# [5 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# day                       0
# pressure                  0
# maxtemp                   0
# temparature               0
# mintemp                   0
# dewpoint                  0
# humidity                  0
# cloud                     0
# rainfall                  0
# sunshine                  0
#          winddirection    1
# windspeed                 1
# dtype: int64

# %%
dataset.shape
# Out:
# (366, 12)

# %%
dataset.columns = dataset.columns.str.strip()

# %%
dataset['winddirection'] = dataset['winddirection'].fillna(dataset['winddirection'].mode()[0])
dataset['windspeed'] = dataset['windspeed'].fillna(dataset['windspeed'].median())

# %%
dataset.isnull().sum()
# Out:
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# rainfall         0
# sunshine         0
# winddirection    0
# windspeed        0
# dtype: int64

# %%
dataset.shape
# Out:
# (366, 12)

# %%
dataset['rainfall'].replace({'yes':1,'no':0}, inplace=True)
# Out:
# /tmp/ipython-input-2640492590.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['rainfall'].replace({'yes':1,'no':0}, inplace=True)
# /tmp/ipython-input-2640492590.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset['rainfall'].replace({'yes':1,'no':0}, inplace=True)

# %%
dataset.head()
# Out:
#    day  pressure  maxtemp  ...  sunshine  winddirection  windspeed
# 0    1    1025.9     19.9  ...       9.3           80.0       26.3
# 1    2    1022.0     21.7  ...       0.6           50.0       15.3
# 2    3    1019.7     20.3  ...       0.0           40.0       14.2
# 3    4    1018.9     22.3  ...       1.0           50.0       16.9
# 4    5    1015.9     21.3  ...       0.0           40.0       13.7
#
# [5 rows x 12 columns]

# %%
dataset.columns = dataset.columns.str.strip()

# %%
dataset.columns
# Out:
# Index(['day', 'pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint',
#        'humidity', 'cloud', 'rainfall', 'sunshine', 'winddirection',
#        'windspeed'],
#       dtype='object')

# %%
dataset = dataset.drop(columns='day')

# %%
dataset.head()
# Out:
#    pressure  maxtemp  temparature  ...  sunshine  winddirection  windspeed
# 0    1025.9     19.9         18.3  ...       9.3           80.0       26.3
# 1    1022.0     21.7         18.9  ...       0.6           50.0       15.3
# 2    1019.7     20.3         19.3  ...       0.0           40.0       14.2
# 3    1018.9     22.3         20.6  ...       1.0           50.0       16.9
# 4    1015.9     21.3         20.7  ...       0.0           40.0       13.7
#
# [5 rows x 11 columns]

# %%
print(dataset['rainfall'].value_counts())
# Out:
# rainfall
# 1    249
# 0    117
# Name: count, dtype: int64

# %%
majority = dataset[dataset['rainfall']==1]
minority = dataset[dataset['rainfall']==0]

# %%
minority.shape
# Out:
# (117, 11)

# %%
majority.shape
# Out:
# (249, 11)

# %%
maj_downsampled = resample(majority, replace=False, n_samples=117, random_state=2)

# %%
dataset = pd.concat([maj_downsampled, minority])

# %%
dataset.shape
# Out:
# (234, 11)

# %%
dataset.head()
# Out:
#      pressure  maxtemp  temparature  ...  sunshine  winddirection  windspeed
# 269    1006.7     32.2         28.7  ...       4.7           90.0       14.0
# 124    1011.4     28.2         25.8  ...       2.7           40.0        9.2
# 235    1000.0     32.9         30.6  ...       7.6          220.0       11.7
# 326    1017.1     27.6         25.4  ...       8.3           80.0       29.2
# 130    1008.1     28.4         26.6  ...       0.3          220.0       12.0
#
# [5 rows x 11 columns]

# %%
dataset = dataset.sample(frac=1,random_state =42).reset_index(drop=True)

# %%
dataset.head()
# Out:
#    pressure  maxtemp  temparature  ...  sunshine  winddirection  windspeed
# 0    1006.5     32.4         30.3  ...       5.2          220.0       28.8
# 1    1013.4     30.8         26.2  ...      10.5           70.0       12.4
# 2    1006.1     33.3         29.6  ...      10.8          220.0        8.7
# 3    1014.4     26.7         23.1  ...       1.2           80.0       19.6
# 4    1021.2     18.6         14.8  ...      10.1           20.0       24.4
#
# [5 rows x 11 columns]

# %%
x = dataset.drop(columns='rainfall')
y = dataset['rainfall']

# %%
x_train, x_test, y_train ,y_test = train_test_split(x,y,test_size=.2,random_state=42)

# %%
model = RandomForestClassifier(random_state = 42)
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              verbose=2)

# %%
best_rf_model = grid_search.best_estimator_
print(grid_search.best_params_)
# Out:
# {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
cv_scores = cross_val_score(best_rf_model, x_train, y_train, cv=5)
print(cv_scores)
print(np.mean(cv_scores))
# Out:
# [0.76315789 0.84210526 0.89189189 0.83783784 0.83783784]
# 0.8345661450924607

# %%
prediction = best_rf_model.predict(x_train)
acc = accuracy_score(y_train,prediction)
print(acc)
# Out:
# 1.0

# %%
prediction = best_rf_model.predict(x_test)
acc = accuracy_score(y_test,prediction)
cff = confusion_matrix(y_test,prediction)
cfr = classification_report(y_test,prediction)
print(cfr)
print(cff)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.67      0.74        24
#            1       0.71      0.87      0.78        23
#
#     accuracy                           0.77        47
#    macro avg       0.78      0.77      0.76        47
# weighted avg       0.78      0.77      0.76        47
#
# [[16  8]
#  [ 3 20]]
# 0.7659574468085106

# %%
new_data = x_test.iloc[[19]]
predict = best_rf_model.predict(new_data)
if predict == 1:
  print("It will rain")
else:
  print("It will not rain")
# Out:
# It will not rain

# %%
model_data = {"model":best_rf_model, "feature_names":x.columns.tolist()}
with open("model.pkl", "wb") as f:
  pickle.dump(model_data, f)

# %%
with open("model.pkl", "rb") as f:
  model_data = pickle.load(f)

# %%
modela = model_data["model"]
feature_names = model_data["feature_names"]

# %%
new_data = x_test.iloc[[19]]
predict = modela.predict(new_data)
if predict == 1:
  print("It will rain")
else:
  print("It will not rain")
# Out:
# It will not rain
