# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import resample

# %%
dataset = pd.read_csv('divorce_da.csv')

# %%
dataset.shape
# Out:
# (170, 55)

# %%
dataset.head()
# Out:
#    Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  ...  Atr50  Atr51  Atr52  Atr53  Atr54  Class
# 0     2     2     4     1     0     0  ...      3      2      3      2      1      1
# 1     4     4     4     4     4     0  ...      4      4      4      2      2      1
# 2     2     2     2     2     1     3  ...      1      1      2      2      2      1
# 3     3     2     3     2     3     3  ...      3      3      2      2      2      1
# 4     2     2     1     1     1     1  ...      2      2      2      1      0      1
#
# [5 rows x 55 columns]

# %%
dataset.describe()
# Out:
#              Atr1        Atr2        Atr3  ...       Atr53       Atr54       Class
# count  170.000000  170.000000  170.000000  ...  170.000000  170.000000  170.000000
# mean     1.776471    1.652941    1.764706  ...    2.241176    2.011765    0.494118
# std      1.627257    1.468654    1.415444  ...    1.505634    1.667611    0.501442
# min      0.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000  ...    1.000000    0.000000    0.000000
# 50%      2.000000    2.000000    2.000000  ...    2.000000    2.000000    0.000000
# 75%      3.000000    3.000000    3.000000  ...    4.000000    4.000000    1.000000
# max      4.000000    4.000000    4.000000  ...    4.000000    4.000000    1.000000
#
# [8 rows x 55 columns]

# %%
dataset.isnull().sum()
# Out:
# Atr1     0
# Atr2     0
# Atr3     0
# Atr4     0
# Atr5     0
# Atr6     0
# Atr7     0
# Atr8     0
# Atr9     0
# Atr10    0
# Atr11    0
# Atr12    0
# Atr13    0
# Atr14    0
# Atr15    0
# Atr16    0
# Atr17    0
# Atr18    0
# Atr19    0
# Atr20    0
# Atr21    0
# Atr22    0
# Atr23    0
# Atr24    0
# Atr25    0
# Atr26    0
# Atr27    0
# Atr28    0
# Atr29    0
# Atr30    0
# Atr31    0
# Atr32    0
# Atr33    0
# Atr34    0
# Atr35    0
# Atr36    0
# Atr37    0
# Atr38    0
# Atr39    0
# Atr40    0
# Atr41    0
# Atr42    0
# Atr43    0
# Atr44    0
# Atr45    0
# Atr46    0
# Atr47    0
# Atr48    0
# Atr49    0
# Atr50    0
# Atr51    0
# Atr52    0
# Atr53    0
# Atr54    0
# Class    0
# dtype: int64

# %%
dataset = dataset.sample(frac=1,random_state =42).reset_index(drop=True)

# %%
dataset.head()
# Out:
#    Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  ...  Atr50  Atr51  Atr52  Atr53  Atr54  Class
# 0     3     1     1     0     0     0  ...      2      2      0      0      4      0
# 1     3     4     3     2     3     0  ...      4      4      4      4      4      1
# 2     0     1     1     0     0     2  ...      2      1      1      1      0      0
# 3     4     3     3     2     4     1  ...      4      4      4      4      4      1
# 4     0     0     2     4     0     0  ...      0      0      1      0      0      0
#
# [5 rows x 55 columns]

# %%
x = dataset.drop(columns = 'Class')
y = dataset['Class']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction = model.predict(x_test)
acc = accuracy_score(y_test,prediction)
print(acc)
# Out:
# 0.9705882352941176

# %%
data = x_test.iloc[[32]]
pred = model.predict(data)
if pred[0] == 0:
    print("Not Divorced")
else:
    print("Divorced")
# Out:
# Divorced

# %%
import pickle

pickle.dump(model,open('divorce.pkl','wb'))

# %%
with open('divorce.pkl','rb') as f:
    model1 = pickle.load(f)

# %%
data = x_test.iloc[[32]]
pred = model1.predict(data)
if pred[0] == 0:
    print("Not Divorced")
else:
    print("Divorced")
# Out:
# Divorced
