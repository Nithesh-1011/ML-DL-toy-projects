# %%
#libraries for image processing
#matplotlib.image
#pillow
#opencv

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/downloadimg.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (224, 225, 3)

# %%
print(img)
# Out:
# [[[167 189 124]
#   [167 189 124]
#   [167 189 124]
#   ...
#   [163 184 117]
#   [163 184 117]
#   [163 184 117]]
#
#  [[167 189 124]
#   [167 189 124]
#   [167 189 124]
#   ...
#   [163 184 117]
#   [163 184 117]
#   [163 184 117]]
#
#  [[168 190 125]
#   [168 190 125]
#   [168 190 125]
#   ...
#   [162 183 116]
#   [162 183 116]
#   [162 183 116]]
#
#  ...
#
#  [[107 127  68]
#   [106 126  65]
#   [106 124  66]
#   ...
#   [124 123  69]
#   [121 115  63]
#   [121 109  59]]
#
#  [[105 124  68]
#   [105 125  66]
#   [106 123  68]
#   ...
#   [118 131  75]
#   [116 125  70]
#   [119 122  69]]
#
#  [[105 124  68]
#   [105 124  68]
#   [106 123  68]
#   ...
#   [117 137  78]
#   [115 133  75]
#   [120 129  74]]]

# %%
plt.imshow(img)

# %%
#resize the image using pillow

from PIL import Image

# %%
img = Image.open('/content/downloadimg.jpg')

# %%
img_resized = img.resize((200,200))

# %%
plt.imshow(img_resized)

# %%
img_resized.save('resized_img.jpg')

# %%
#some models only accepts particular size

# %%
imgr = plt.imread('/content/resized_img.jpg')

# %%
imgr.shape
# Out:
# (200, 200, 3)

# %%
#rgb to grayscale

# %%
import cv2 #opencv

# %%
img2 = cv2.imread('/content/resized_img.jpg')

# %%
grayscaled = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)

# %%
type(grayscaled)
# Out:
# numpy.ndarray

# %%
grayscaled.shape
# Out:
# (200, 200)

# %%
plt.imshow(grayscaled, cmap='gray')

# %%
cv2.imwrite('grayscale_img.jpg', grayscaled)
# Out:
# True
